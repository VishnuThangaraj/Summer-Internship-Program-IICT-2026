# %% [markdown]
# **Name of Student:** Vishnu Thangaraj
# **Roll Number:** 845488

# %% [markdown]
# ## Assignment 1

# %%
import numpy as np
import pandas as pd

# %%
a = 10
b = 20

print(a+b)
# Out:
# 30

# %%
print("Hello World")
# Out:
# Hello World
